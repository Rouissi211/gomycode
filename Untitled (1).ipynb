# %%
import pandas as pd
df1=pd.read_csv(r'df2.csv')
df1.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-101-2ee0eee860aa> in <module>()
#       1 import pandas as pd
# ----> 2 df1=pd.read_csv(r'df2.csv')
#       3 df1.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 3, saw 2

# %%
df1
# Out:
#      Unnamed: 0  PassengerId  Survived  ...     Fare  Embarked  FamilySize
# 0             0          343         0  ...  13.0000         2           0
# 1             1           76         0  ...   7.6500         2           0
# 2             2          641         0  ...   7.8542         2           0
# 3             3          568         0  ...  21.0750         2           4
# 4             4          672         0  ...  52.0000         2           1
# ..          ...          ...       ...  ...      ...       ...         ...
# 886         886           10         1  ...  30.0708         0           1
# 887         887           61         0  ...   7.2292         0           0
# 888         888          535         0  ...   8.6625         2           0
# 889         889          102         0  ...   7.8958         2           0
# 890         890          428         1  ...  26.0000         2           0
#
# [891 rows x 11 columns]

# %%
def preprocess_data(new_data):
    new_data['Age'].fillna(new_data['Age'].mean(),inplace=True)
    new_data.replace({'Sex':{'male': 1,'female':0}},inplace=True)
    new_data['Cabin']=new_data.Cabin.fillna('G6')
    new_data.replace({'Survived':{'Yes': 1,'No':0}},inplace=True)
    return new_data
    data=preprocess_data(dataset) 
from sklearn.model_selection import train_test_split
from sklearn import tree   
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
x=df1.drop(["Survived", "Ticket", "Embarked"], axis=1)
y= df1["Survived"]
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3,random_state=10)
tre = tree.DecisionTreeClassifier()  
tre.fit(x_train, y_train)   
y_pred=tre.predict(x_test)  
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.746268656716418

# %%
from sklearn.tree import export_graphviz
import graphviz
from sklearn import tree
dot_data=tree.export_graphviz(tre, out_file=None)
graph=graphviz.Source(dot_data)

# %%
from sklearn.tree import export_graphviz
import graphviz

export_graphviz(tre, out_file="data")
with open("data") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree   
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
x=df1.drop(["Age", "Fare"], axis=1)
y= df1["Survived"]
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3,random_state=10)
tre = tree.DecisionTreeClassifier()  
tre.fit(x_train, y_train)   
y_pred=tre.predict(x_test)  
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:1.0

# %%
from sklearn import metrics 
clf=RandomForestClassifier(n_estimators=10)  
clf.fit(x_train, y_train)  
y_pred=clf.predict(x_test)  
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
x
